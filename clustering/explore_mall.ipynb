# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind

import acquire_mall
import prepare_mall

# %%
df = acquire_mall.get_mall_data()

# %%
df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
df = prepare_mall.is_outlier(df)

# %%
df = prepare_mall.encode_mall(df)
# Out:
# gender_encoded
# spending_score_encoded

# %%
df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score  \
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40
#
#    annual_income_outliers  gender_encoded  spending_score_encoded
# 0                     0.0               1                      30
# 1                     0.0               1                      67
# 2                     0.0               0                       4
# 3                     0.0               0                      64
# 4                     0.0               0                      31

# %%
ttest_ind(df.gender_encoded, df.annual_income)
